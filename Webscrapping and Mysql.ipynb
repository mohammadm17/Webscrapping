# %%
from bs4 import BeautifulSoup as bs
import selenium
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())
import time
import pandas as pd
# Out:
# [WDM] - Downloading:   0%|                                                                 | 0.00/2.55k [00:00<?, ?B/s]<ipython-input-1-5e8166184ecd>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())
# [WDM] - Downloading: 19.0kB [02:04, 156B/s]

# %%
#EXTRACTING DATA FROM WEBSITE

# %%
url1 = 'https://www.careerguide.com/career-options'

# %%
driver.get(url1)

# %%
all_jobs0 = driver.find_element(By.CLASS_NAME, 'c-body').text

# %%
all_jobs = all_jobs0.split("\n")

# %%
a122 = driver.find_elements(By.CLASS_NAME, 'col-md-4')

# %%
newlist = []
for i in driver.find_elements(By.CLASS_NAME, 'col-md-4'):
    newlist.append(i.text)

# %%
newlist
# Out:
# ['Aerospace & Aviation\nAirline Pilot\nAerospace Materials Specialist\nAir Traffic Controller\nAircraft Cleaner\nAircraft Maintenance Technician\nAircraft Refueller\nTerminal Operations Manager\nReservation and Ticketing Agent\nRamp Service Agent\nGround Operation Staff\nCabin Crew/Flight Attendant\nBaggage and Cargo Handler\nAvionics and ElectronicsTechnician\nAirport security Executive\nAircraft Structures Technician\nCommercial Pilot',
#  'Agriculture\nAgriculture & Allied Fields\nBiological Scientist\nDietitian\nEnvironmental scientist\nFishery Scientist\nFood Technologists\nGeographers  \nGeologists\nIndian Forest Service Officer  \nMeteorologist\nNutritionists\nOceanographers\nZoologists\nCrop Farmer\nFarm Eqipment Mechanic\nFisheries\nGardener\nGreenhouse Fitter\nHorticulture Farmer\nMicro Irrigation Technician\nPesticide Handler\nPoultry Farmer\nPump Operator\nTea Plantation Worker\nTractor Servicing/Operator\nVegetable Farmer',
# ...

# %%
new_list = newlist[0]

# %%
listToStr = ''.join([str(elem) for elem in new_list])

# %%
listToStr
# Out:
# 'Aerospace & Aviation\nAirline Pilot\nAerospace Materials Specialist\nAir Traffic Controller\nAircraft Cleaner\nAircraft Maintenance Technician\nAircraft Refueller\nTerminal Operations Manager\nReservation and Ticketing Agent\nRamp Service Agent\nGround Operation Staff\nCabin Crew/Flight Attendant\nBaggage and Cargo Handler\nAvionics and ElectronicsTechnician\nAirport security Executive\nAircraft Structures Technician\nCommercial Pilot'

# %%
new_jobs1 = listToStr.split("\n")

# %%
new_jobs1
# Out:
# ['Aerospace & Aviation',
#  'Airline Pilot',
#  'Aerospace Materials Specialist',
#  'Air Traffic Controller',
#  'Aircraft Cleaner',
#  'Aircraft Maintenance Technician',
#  'Aircraft Refueller',
#  'Terminal Operations Manager',
#  'Reservation and Ticketing Agent',
#  'Ramp Service Agent',
#  'Ground Operation Staff',
#  'Cabin Crew/Flight Attendant',
#  'Baggage and Cargo Handler',
#  'Avionics and ElectronicsTechnician',
#  'Airport security Executive',
#  'Aircraft Structures Technician',
#  'Commercial Pilot']

# %%
driver.get("https://www.linkedin.com/jobs/search/?alertAction=viewjobs&currentJobId=3307738523&geoId=106164952&location=Mumbai%2C%20Maharashtra%2C%20India&refresh=true")
from selenium.webdriver.common.keys import Keys
from time import sleep, strftime

# %%
#SEARCHING THE JOBS

# %%
input = driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/section/section[2]/form/section[1]/input")

# %%
input.send_keys(new_jobs1[4])

# %%
input.send_keys(Keys.ENTER)

# %%
clear_searchindex = driver.find_element(By.XPATH, "/html/body/div[1]/header/nav/section/section[2]/form/section[1]/button")

# %%
clear_searchindex.send_keys(Keys.ENTER)

# %%
new1 = driver.find_elements(By.XPATH,"/html/body/div[1]/div/main/section[2]/ul/li[2]/div/a")

# %%
new11 = driver.find_elements(By.XPATH,'/html/body/div[1]/div/main/section[2]')

# %%
for i in new11:
    print(i)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="43ffa62e-2e1a-4fe0-8a9f-1683a0e3f56e", element="cd381471-5a6e-493c-b99b-c370ac47644a")>

# %%
add = []
for i in new11:
    NEWW = i.get_attribute('outerHTML')
    add.append(NEWW)

# %%
NEWW
# Out:
# '<section class="two-pane-serp-page__results-list">\n              \n          <ul class="jobs-search__results-list">\n              <li>\n                \n\n    \n\n    \n    \n      \n\n    \n      <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card job-search-card--active" data-entity-urn="urn:li:jobPosting:3299674782" data-search-id="oMwQ5iEysrwW7+g6AZehJg==" data-tracking-id="xsEI2ytX3MgmVbMwGZEaLA==" data-column="1" data-row="1" data-visible-time="1665840140246" data-largest-intersection-ratio="1">\n        \n\n        <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" href="https://in.linkedin.com/jobs/view/emergency-cleaning-and-maintenance-officer-at-tradeflex-3299674782?refId=oMwQ5iEysrwW7%2Bg6AZehJg%3D%3D&amp;trackingId=xsEI2ytX3MgmVbMwGZEaLA%3D%3D&amp;position=1&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card" data-tracking-control-name
# ...

# %%
len(add)
# Out:
# 1

# %%
soup = bs(NEWW,'html.parser')

# %%
a = soup.get_text()
new_listt = a.split("\n")

# %%
new_listt
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '            ',
#  '        ',
#  '        Emergency Cleaning and Maintenance Officer',
#  '      ',
#  '      ',
#  '          ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '            ',
#  '        Emergency Cleaning and Maintenance Officer',
#  '      ',
#  '          ',
#  '',
#  '',
#  '            Tradeflex',
#  '          ',
#  '',
#  '',
#  '',
#  '',
#  '            Eastern Suburbs, Maharashtra, India',
#  '          ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '         Be an early applicant',
#  ' ',
#  '',
#  '',
#  '',
#  '',
#  '            ',
#  '',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '    ',
#  '',
#  '    2 weeks ago',
# ...

# %%
res = []
for ele in new_listt:
    if ele.strip():
        res.append(ele)

# %%
res
# Out:
# ['        Emergency Cleaning and Maintenance Officer',
#  '        Emergency Cleaning and Maintenance Officer',
#  '            Tradeflex',
#  '            Eastern Suburbs, Maharashtra, India',
#  '         Be an early applicant',
#  '    2 weeks ago',
#  '        Domestic Assistance / Cleaner - City/ Eastern Suburbs',
#  '        Domestic Assistance / Cleaner - City/ Eastern Suburbs',
#  '            Anglicare Sydney',
#  '            Eastern Suburbs, Maharashtra, India',
#  '         Be an early applicant',
#  '    1 month ago',
#  "        You've viewed all jobs for this search"]

# %%
a = 0
for i in res:
    print(i, a)
    a = a+1
# Out:
#         Emergency Cleaning and Maintenance Officer 0
#         Emergency Cleaning and Maintenance Officer 1
#             Tradeflex 2
#             Eastern Suburbs, Maharashtra, India 3
#          Be an early applicant 4
#     2 weeks ago 5
#         Domestic Assistance / Cleaner - City/ Eastern Suburbs 6
#         Domestic Assistance / Cleaner - City/ Eastern Suburbs 7
#             Anglicare Sydney 8
#             Eastern Suburbs, Maharashtra, India 9
#          Be an early applicant 10
#     1 month ago 11
#         You've viewed all jobs for this search 12

# %%
company_name= res[2::6]

# %%
company_name
# Out:
# ['            Tradeflex', '            Anglicare Sydney']

# %%
job_position = res[1::6]

# %%
job_position
# Out:
# ['        Emergency Cleaning and Maintenance Officer',
#  '        Domestic Assistance / Cleaner - City/ Eastern Suburbs']

# %%
Location = res[3::6]

# %%
Location
# Out:
# ['            Eastern Suburbs, Maharashtra, India',
#  '            Eastern Suburbs, Maharashtra, India']

# %%
job_posted= res[5::6]

# %%
job_posted
# Out:
# ['    2 weeks ago', '    1 month ago']

# %%
href_tags = soup.find_all(href=True)
href_tags
# Out:
# [<a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/emergency-cleaning-and-maintenance-officer-at-tradeflex-3299674782?refId=oMwQ5iEysrwW7%2Bg6AZehJg%3D%3D&amp;trackingId=xsEI2ytX3MgmVbMwGZEaLA%3D%3D&amp;position=1&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
#  <span class="sr-only">
#
#
#          Emergency Cleaning and Maintenance Officer
#
#
#            </span>
#  </a>,
#  <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://au.linkedin.com/company/tradeflex?trk=public_jobs_jserp-result_job-search-card-subtitle">
#              Tradeflex
#            </a>,
# ...

# %%
job_link= []
for a22 in soup.find_all('a', href=True):
    job_link.append(a22['href'])

# %%
job_link
# Out:
# ['https://in.linkedin.com/jobs/view/emergency-cleaning-and-maintenance-officer-at-tradeflex-3299674782?refId=oMwQ5iEysrwW7%2Bg6AZehJg%3D%3D&trackingId=xsEI2ytX3MgmVbMwGZEaLA%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card',
#  'https://au.linkedin.com/company/tradeflex?trk=public_jobs_jserp-result_job-search-card-subtitle',
#  'https://in.linkedin.com/jobs/view/domestic-assistance-cleaner-city-eastern-suburbs-at-anglicare-sydney-3295297025?refId=oMwQ5iEysrwW7%2Bg6AZehJg%3D%3D&trackingId=gkTAd2y6FTRA6HEe0z8I9g%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card',
#  'https://au.linkedin.com/company/anglicare-sydney?trk=public_jobs_jserp-result_job-search-card-subtitle']

# %%
apply_link = job_link[0::2]
len(apply_link)
# Out:
# 2

# %%
apply_link[0]
# Out:
# 'https://in.linkedin.com/jobs/view/emergency-cleaning-and-maintenance-officer-at-tradeflex-3299674782?refId=oMwQ5iEysrwW7%2Bg6AZehJg%3D%3D&trackingId=xsEI2ytX3MgmVbMwGZEaLA%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'

# %%
company_profile_link = job_link[1::2]

# %%
company_profile_link[0]
# Out:
# 'https://au.linkedin.com/company/tradeflex?trk=public_jobs_jserp-result_job-search-card-subtitle'

# %%
#ESTABLISHING THE SQL CONNECTION

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost',user = 'root', passwd = "sharique@123")

# %%
cursor = mydb.cursor()
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testm17',),
#  ('webscrapping',),
#  ('world',)]

# %%
cursor.execute("create database webscrapping")

# %%
cursor.execute("create table webscrapping.ws(Job_DOMAIN VARCHAR(500), JOB_CATEGORIES VARCHAR(500),JOB_POSITION VARCHAR(500), COMPANY_NAME VARCHAR(300), STATES VARCHAR(3000), Company_link VARCHAR(10000))")

# %%
mydb.commit()

# %%
cursor.execute('use webscrapping')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('ws',)]

# %%
for i in range(len(job_position)):
#i = 0
    data=('insert into webscrapping.ws values(%s,%s,%s,%s,%s, %s)'),("Aerospace & Aviation", "Aerospace Materials Specialist",job_position[i],company_name[i],Location[i],company_profile_link[i])
    cursor.execute(*data)

# %%
cursor.execute("select * from webscrapping.ws")

# %%
cursor.fetchall()
# Out:
# [('Aerospace & Aviation',
#   'Aerospace Materials Specialist',
#   '        Emergency Cleaning and Maintenance Officer',
#   '            Tradeflex',
#   '            Eastern Suburbs, Maharashtra, India',
#   'https://au.linkedin.com/company/tradeflex?trk=public_jobs_jserp-result_job-search-card-subtitle'),
#  ('Aerospace & Aviation',
#   'Aerospace Materials Specialist',
#   '        Domestic Assistance / Cleaner - City/ Eastern Suburbs',
#   '            Anglicare Sydney',
#   '            Eastern Suburbs, Maharashtra, India',
#   'https://au.linkedin.com/company/anglicare-sydney?trk=public_jobs_jserp-result_job-search-card-subtitle')]

# %%
#CREATING A DATAFRAME FOR BETTER VISUALISATION

# %%
for i in range(len(job_position)):
       df1= pd.DataFrame({f'Job_DOMAIN':"Aerospace & Aviation",
           'JOB_CATEGORIES':"Aerospace Materials Specialist",
           'JOB_POSITION':(job_position[i]), 
           'COMPANY_NAME':company_name[i],
           'STATES':Location[i]
                  },index= [0])

# %%
df1
# Out:
#              Job_DOMAIN                  JOB_CATEGORIES  \
# 0  Aerospace & Aviation  Aerospace Materials Specialist
#
#                                         JOB_POSITION  \
# 0          Domestic Assistance / Cleaner - City/ ...
#
#                    COMPANY_NAME  \
# 0              Anglicare Sydney
#
#                                             STATES
# 0              Eastern Suburbs, Maharashtra, India

# %%
aq
# Out:
# [['Aerospace & Aviation',
#   'Aerospace Materials Specialist',
#   '        Associate Materials & Processes Research Engineer',
#   '            Boeing',
#   '            Bengaluru, Karnataka, India',
#   'https://www.linkedin.com/company/boeing?trk=public_jobs_jserp-result_job-search-card-subtitle',
#   'https://in.linkedin.com/jobs/view/associate-materials-processes-research-engineer-at-boeing-3316355198?refId=BEESpInzby2TCFLJnCg%2Bfg%3D%3D&trackingId=cHP3Faf5aWO44o8VpWb4lQ%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'],
#  ['Aerospace & Aviation',
#   'Aerospace Materials Specialist',
#   '        Manufacturing Engineer - Materials & processes',
#   '            GKN Fokker',
#   '            Bengaluru, Karnataka, India',
#   'https://www.linkedin.com/company/gknfokker-aerospace?trk=public_jobs_jserp-result_job-search-card-subtitle',
# ...

# %%
 for i in range(0,5):
       df1= df1.append({f'Job_DOMAIN':"Aerospace & Aviation",
           'JOB_CATEGORIES':"Aerospace Materials Specialist",
           'JOB_POSITION':(job_position[i]), 
           'COMPANY_NAME':company_name[i],
           'STATES':Location[i],
           'COMPANY_LINKEDIN':company_profile_link[i],
           'APPLY_LINK':apply_link[i]
                  }, ignore_index=True)

# %%
df1
# Out:
#              Job_DOMAIN                  JOB_CATEGORIES  \
# 0  Aerospace & Aviation  Aerospace Materials Specialist
# 1  Aerospace & Aviation  Aerospace Materials Specialist
# 2  Aerospace & Aviation  Aerospace Materials Specialist
# 3  Aerospace & Aviation  Aerospace Materials Specialist
# 4  Aerospace & Aviation  Aerospace Materials Specialist
#
#                                         JOB_POSITION            COMPANY_NAME  \
# 0          Associate Materials & Processes Resear...                  Boeing
# 1          Manufacturing Engineer - Materials & p...              GKN Fokker
# 2              Lead Associate Material Science-India              Kennametal
# 3              Lead Associate Material Science-India              Kennametal
# 4                          Sr. Executive - Materials                  Cyient
#
#                                     STATES  \
# 0              Bengaluru, Karnataka, India
# 1              Bengaluru, Karnataka, India
# ...

# %%
import time
